# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
import os

# %%
save_dir="images/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
query="ant"
link="https://www.google.com/search?q=ant&sxsrf=APwXEdeh3xLJCJb7vT3pQqunpknH9V3QZw:1685417438791&source=lnms&tbm=isch&sa=X&ved=2ahUKEwi90PKdjZz_AhWsmlYBHaRWAgsQ_AUoAXoECAEQAw&biw=1488&bih=778&dpr=1.25"

# %%
response=urlopen(f"https://www.google.com/search?q={query}&sxsrf=APwXEdeh3xLJCJb7vT3pQqunpknH9V3QZw:1685417438791&source=lnms&tbm=isch&sa=X&ved=2ahUKEwi90PKdjZz_AhWsmlYBHaRWAgsQ_AUoAXoECAEQAw&biw=1488&bih=778&dpr=1.25")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response=urlopen(f"https://www.google.com/search?q={query}&sxsrf=APwXEdeh3xLJCJb7vT3pQqunpknH9V3QZw:1685417438791&source=lnms&tbm=isch&sa=X&ved=2ahUKEwi90PKdjZz_AhWsmlYBHaRWAgsQ_AUoAXoECAEQAw&biw=1488&bih=778&dpr=1.25")
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# ...

# %%
import requests

# %%
response=requests.get(link)

# %%
response.content
# Out:
# b'<!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd"><html xmlns="http://www.w3.org/1999/xhtml" lang="en-IN"><head><meta content="application/xhtml+xml; charset=UTF-8" http-equiv="Content-Type"/><meta content="no-cache" name="Cache-Control"/><title>ant - Google Search</title><style>a{text-decoration:none;color:inherit}a:hover{text-decoration:underline}a img{border:0}body{font-family:arial,sans-serif;padding:8px;margin:0 auto;max-width:700px;min-width:240px;}.FbhRzb{border-left:thin solid #dadce0;border-right:thin solid #dadce0;border-top:thin solid #dadce0;height:40px;overflow:hidden}.n692Zd{margin-bottom:10px}.cvifge{height:40px;border-spacing:0}.QvGUP{height:40px;padding:0 8px 0 8px;vertical-align:top}.O4cRJf{height:40px;width:100%;padding:0;padding-right:16px}.O1ePr{height:40px;padding:0;vertical-align:top}.kgJEQe{height:36px;width:98px;vertical-align:top;margin-top:4px}.lXLRf{vertical-align:top}.MhzMZd{border:0;vertical-
# ...

# %%
soup=bs(response.content)
soup
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
image=soup.find_all("img")

# %%
image[0]['src']
# Out:
# '/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif'

# %%
del image[0]

# %%
image[0]['src']
# Out:
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQmqUVoB51DKOnSdT6XqcTtPXzFkuGdbZvAebFkEVQpRyfqTrC5thOrm04CnPc&s'

# %%
image_urls=[image[i]['src'] for i in range(len(image))]
image_urls
# Out:
# ['https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQmqUVoB51DKOnSdT6XqcTtPXzFkuGdbZvAebFkEVQpRyfqTrC5thOrm04CnPc&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTcZW89ij8jTTfLxoKOCXAkphBxOfp4Ua3FPU0iDx4LwZr3vm-tKJWUZ-KtCms&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ1uyiPO6ESmq1MtIXfj2hREKxyKO789RE3p_qtKcOrjXwVfZU0rSK2YUL12Q&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSdYwPk4XS1X4-SO8pNkx4n0hidnxaophAW6uWfa01j50CvBUtr00eFGv__tg&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT257r3YRkIxLkzeq71-BsZVkhfxmqnVbkJnK73F-ayOMb-l1XYNSKDyAy2fw&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQcrzQQ2aeEK2j77SxmoDZBwtE8Qx6vLpQmnCmyVSIJM9tHFUvy4x5NSt6Lwuo&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQabaUjaKf3ZqeYIRJAT1C5KkLjzGZ-Y5PzGaJ3UNjsVfvkGPzUyS1Gn76-Mw&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSiGVKMhjIIY5mEQsQdSDhTXezVIP6SNv5_0jKWnw8gwAAqBTikHz00aBvx1g&s',
# ...

# %%
img_data=[]
i=0
for img in image_urls:
    image=requests.get(img).content
    img_dict={f"{i}":image}
    img_data.append(img_dict)
    i=i+1

# %%
import pymongo
client=pymongo.MongoClient("mongodb+srv://rahim_khan:HLP4fumDmpJwOH9D@cluster0.7s0dot2.mongodb.net/?retryWrites=true&w=majority")

# %%
img_rec=client['img_scrap']
img_coll=img_rec['img_col']
img_coll.insert_many(img_data)

# %%
img_data
# Out:
# [{'0': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x08\x07\x06\t\x08\x07\x08\n\n\t\x0b\r\x16\x0f\r\x0c\x0c\r\x1b\x14\x15\x10\x16 \x1d"" \x1d\x1f\x1f$(4,$&1\'\x1f\x1f-=-157:::#+?D?8C49:7\x01\n\n\n\r\x0c\r\x1a\x0f\x0f\x1a7%\x1f%77777777777777777777777777777777777777777777777777\xff\xc0\x00\x11\x08\x00]\x00\xa2\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x06\x01\x04\x07\x02\x03\x08\xff\xc4\x00:\x10\x00\x01\x03\x03\x02\x04\x03\x05\x05\x08\x02\x03\x00\x00\x00\x00\x01\x02\x03\x04\x00\x05\x11\x12!\x061AQ\x13aq\x07\x14"2\x813Bb\xa1\xb1\x15#Rr\x91\x92\xc1\xd1\x82\xe1\x17C\xc2\xff\xc4\x00\x16\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\xff\xc4\x00\x1b\x11\x01\x01\x01\x00\x02\x03\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x11!1\x02\x12A\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xee4\xa5(\x14\xa5(\x15\xe5
# ...

# %%
x=img_coll.find()[0]['0']
f=open('./images/img.jpeg','wb')
f.write(x)
f.close()
